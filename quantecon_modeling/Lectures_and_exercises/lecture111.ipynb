# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 200)
titas = np.linspace(0, 2, 10)
def y(x,tita):
    return np.cos(np.pi * tita * x) * np.exp(-x)

fig, ax = plt.subplots()

for tita in titas:
    ax.plot(x, y(x, tita))

plt.show()
